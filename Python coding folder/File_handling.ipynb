# %%
from pyspark.sql.functions import *

# %%
import requests

response = requests.get("https://jsonplaceholder.typicode.com/posts")
data = response.json()
df = spark.createDataFrame(data)
display(df)

# %%
# %sql

create volume default.volume1;

# %%
file = open("sample.txt", "w+")

# %%
df.write.csv(
  "/Volumes/workspace/default/volume1/sample_data",
  mode="overwrite"
)

# %%
df1 = spark.read.option("header", "true").csv("/Volumes/workspace/default/volume1/sample_data")
display(df1)

# %%
f1 = open(
  "/Volumes/workspace/default/volume1/sample_data/sample.txt",
  "a+"
)
f1.write("This is maylavarapu naga siva kumar appended data")
f1.close()

# %%
df2 = spark.read.csv("/Volumes/workspace/default/volume1/sample_data/sample.txt")
_c = df2.count()

# %%
if _c >= 0:
    print("data is not empthy")
    df2.display()
else:
    print("data is empty")
